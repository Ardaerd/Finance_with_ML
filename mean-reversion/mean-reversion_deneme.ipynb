# %%
import yfinance as yf
from IPython.display import display
import plotly.graph_objects as go

# %%
ticker = "JPM"

data = yf.download(ticker, start="2018-01-01", end="2024-11-29")

data.reset_index(inplace=True)
data.columns = [col[0] if col[1] == '' else col[0] for col in data.columns]


# columns_to_keep = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# data = data[columns_to_keep]

print(data.columns)
print(data.index)

display(data.head())
display(data.tail())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Index(['Date', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
# RangeIndex(start=0, stop=1739, step=1)
#         Date  Adj Close       Close        High         Low        Open  \
# 0 2018-01-02  88.566338  107.949997  108.019997  106.809998  107.629997
# 1 2018-01-03  88.656601  108.059998  108.489998  107.480003  107.860001
# 2 2018-01-04  89.926643  109.040001  110.029999  108.199997  108.360001
# 3 2018-01-05  89.349350  108.339996  109.550003  107.779999  109.260002
# 4 2018-01-08  89.481300  108.500000  108.680000  107.699997  108.150002
#
#      Volume
# 0  13578800
# 1  11901000
# 2  12953700
# 3  14155000
# 4  12466500
#            Date   Adj Close       Close        High         Low        Open  \
# 1734 2024-11-21  244.759995  244.759995  245.490005  242.110001  243.229996
# 1735 2024-11-22  248.550003  248.550003  249.149994  243.029999  243.610001
# 1736 2024-11-25  250.289993  250.289993  254.309998  249.059998  249.589996
# 1737 2024-11-26  249.970001  249.970001  251.000000  248.339996  250.490005
# 1738 2024-11-27  249.789993  249.789993  251.190002  248.770004  249.350006
#
#         Volume
# 1734   8783500
# 1735   7997300
# 1736  10295400
# 1737   6212100
# 1738   5472300

# %%
data
# Out:
#            Date   Adj Close       Close        High         Low        Open  \
# 0    2018-01-02   88.566338  107.949997  108.019997  106.809998  107.629997
# 1    2018-01-03   88.656601  108.059998  108.489998  107.480003  107.860001
# 2    2018-01-04   89.926643  109.040001  110.029999  108.199997  108.360001
# 3    2018-01-05   89.349350  108.339996  109.550003  107.779999  109.260002
# 4    2018-01-08   89.481300  108.500000  108.680000  107.699997  108.150002
# ...         ...         ...         ...         ...         ...         ...
# 1734 2024-11-21  244.759995  244.759995  245.490005  242.110001  243.229996
# 1735 2024-11-22  248.550003  248.550003  249.149994  243.029999  243.610001
# 1736 2024-11-25  250.289993  250.289993  254.309998  249.059998  249.589996
# 1737 2024-11-26  249.970001  249.970001  251.000000  248.339996  250.490005
# 1738 2024-11-27  249.789993  249.789993  251.190002  248.770004  249.350006
#
#         Volume
# 0     13578800
# 1     11901000
# 2     12953700
# 3     14155000
# 4     12466500
# ...        ...
# 1734   8783500
# 1735   7997300
# 1736  10295400
# 1737   6212100
# 1738   5472300
#
# [1739 rows x 7 columns]

# %%
window_size = 20

data_rolling = data.copy()

data_rolling["mean"] = data_rolling["Adj Close"].rolling(window_size).mean()
data_rolling["std"] = data_rolling["Adj Close"].rolling(window_size).std()

data_rolling = data_rolling.dropna()


display(data_rolling.head(30))
# Out:
#          Date  Adj Close       Close        High         Low        Open  \
# 19 2018-01-30  94.932648  115.110001  116.599998  114.980003  115.529999
# 20 2018-01-31  95.394501  115.669998  116.660004  115.160004  115.650002
# 21 2018-02-01  96.384155  116.870003  116.989998  115.480003  115.769997
# 48  13312300  95.248524  1.350291

# %%
k = 2

data_rolling["zscore"] = (data_rolling["Adj Close"] - data_rolling["mean"]) / data_rolling["std"]

# Initialize signal column
data_rolling["signal"] = 0

# Generate buy signals
data_rolling.loc[
    (data_rolling["zscore"] < -k) &
    (data_rolling["Adj Close"] < data_rolling["mean"] - k * data_rolling["std"]),
    "signal"
] = 1

# Generate sell signals
data_rolling.loc[
    (data_rolling["zscore"] > k) &
    (data_rolling["Adj Close"] > data_rolling["mean"] + k * data_rolling["std"]),
    "signal"
] = -1

display(data_rolling)
# Out:
#            Date   Adj Close       Close        High         Low        Open  \
# 19   2018-01-30   94.932648  115.110001  116.599998  114.980003  115.529999
# 20   2018-01-31   95.394501  115.669998  116.660004  115.160004  115.650002
# 21   2018-02-01   96.384155  116.870003  116.989998  115.480003  115.769997
# 22   2018-02-02   94.248161  114.279999  116.919998  114.089996  116.489998
# 23   2018-02-05   89.728714  108.800003  114.589996  103.980003  113.000000
# ...         ...         ...         ...         ...         ...         ...
# 1734 2024-11-21  244.759995  244.759995  245.490005  242.110001  243.229996
# 1735 2024-11-22  248.550003  248.550003  249.149994  243.029999  243.610001
# 1736 2024-11-25  250.289993  250.289993  254.309998  249.059998  249.589996
# 1737 2024-11-26  249.970001  249.970001  251.000000  248.339996  250.490005
# 1738 2024-11-27  249.789993  249.789993  251.190002  248.770004  249.350006
#
#         Volume        mean        std    zscore  signal
# 19    14279100   92.477100   2.511614  0.977677       0
# 20    13141400   92.818508   2.414233  1.067003       0
# 21    13800600   93.204885   2.329993  1.364497       0
# 22    16477300   93.420961   2.207121  0.374787       0
# 23    30097600   93.439930   2.171632 -1.708952       0
# ...        ...         ...        ...       ...     ...
# 1734   8783500  234.125999  10.004958  1.062873       0
# 1735   7997300  235.437999  10.094010  1.298989       0
# 1736  10295400  236.677499  10.328760  1.317922       0
# 1737   6212100  238.030999  10.201171  1.170356       0
# 1738   5472300  239.299998   9.994075  1.049621       0
#
# [1720 rows x 11 columns]

# %%
data_rolling["buy_signal"] = data_rolling["Adj Close"].where(data_rolling["signal"] == 1)
data_rolling["sell_signal"] = data_rolling["Adj Close"].where(data_rolling["signal"] == -1)

fig = go.Figure()

# Add the Adj Close price line
fig.add_trace(go.Scatter(
    x=data_rolling["Date"],
    y=data_rolling["Adj Close"],
    mode='lines',
    name='Adj Close',
    line=dict(color='blue')
))

# Add buy signals
fig.add_trace(go.Scatter(
    x=data_rolling["Date"],
    y=data_rolling["buy_signal"],
    mode='markers',
    name='Buy Signal',
    marker=dict(color='green', size=10, symbol='triangle-up')
))

# Add sell signals
fig.add_trace(go.Scatter(
    x=data_rolling["Date"],
    y=data_rolling["sell_signal"],
    mode='markers',
    name='Sell Signal',
    marker=dict(color='red', size=10, symbol='triangle-down')
))

# Add the upper threshold line
fig.add_trace(go.Scatter(
    x=data_rolling["Date"],
    y=upper_threshold,
    mode='lines',
    name='Upper Threshold',
    line=dict(color='orange', width=1)  # Thinner line
))

# Add the lower threshold line
fig.add_trace(go.Scatter(
    x=data_rolling["Date"],
    y=lower_threshold,
    mode='lines',
    name='Lower Threshold',
    line=dict(color='purple', width=1)  # Thinner line
))

# Add layout details
fig.update_layout(
    title="Trading Signals with Upper and Lower Bounds",
    xaxis_title="Date",
    yaxis_title="Price",
    legend=dict(orientation='h', yanchor='bottom', y=1.02, xanchor='right', x=1),
    template='plotly_white'
)

# Show the figure
fig.show()

# %%
data_rolling.reset_index(drop=True, inplace=True)

# %%
base_allocation = 0.1  # Start with 10% allocation
data_rolling["dynamic_allocation"] = 0

# Initialize a counter for consecutive buy/sell signals
consecutive_signal = 0

# Iterate through the DataFrame to calculate dynamic allocation
for i in range(1, len(data_rolling)):

    if data_rolling.loc[i, "signal"] == 1 and data_rolling.loc[i-1, "dynamic_allocation"] < 1:  # Buy signal

        if data_rolling.loc[i - 1, "signal"] == 1 and data_rolling.loc[i - 1, "Adj Close"] > data_rolling.loc[i, "Adj Close"]:  # Previous was also a buy
            consecutive_signal += 1

        else:
            consecutive_signal = 1  # Reset counter if switching from sell to buy

        if data_rolling.loc[i - 1, "dynamic_allocation"] + (base_allocation * consecutive_signal) <= 1:
            data_rolling.loc[i, "dynamic_allocation"] = (base_allocation * consecutive_signal) + data_rolling.loc[i - 1, "dynamic_allocation"]
        
        else:
            data_rolling.loc[i, "dynamic_allocation"] = 1

    elif data_rolling.loc[i, "signal"] == -1 and data_rolling.loc[i-1, "dynamic_allocation"] > 0:  # Sell signal

        if data_rolling.loc[i - 1, "signal"] == -1 and data_rolling.loc[i - 1, "Adj Close"] < data_rolling.loc[i, "Adj Close"]:  # Previous was also a sell
            consecutive_signal += 1

        else:
            consecutive_signal = 1  # Reset counter if switching from buy to sell

        if data_rolling.loc[i - 1, "dynamic_allocation"] - (base_allocation * consecutive_signal) >= 0:
            data_rolling.loc[i, "dynamic_allocation"] = data_rolling.loc[i - 1, "dynamic_allocation"] - (base_allocation * consecutive_signal)

        else: 
            data_rolling.loc[i, "dynamic_allocation"] = 0
            
    else:  # Hold signal
        data_rolling.loc[i, "dynamic_allocation"] = data_rolling.loc[i - 1, "dynamic_allocation"]  # Carry forward

# Calculate the position based on dynamic allocation
data_rolling["position"] = data_rolling["dynamic_allocation"] * data_rolling["signal"]
data_rolling["position"] = data_rolling["position"].replace(to_replace=0, method='ffill')

# Calculate returns based on position and price changes
data_rolling["returns"] = data_rolling["position"].shift() * data_rolling["Adj Close"].pct_change()

# Drop rows with NaN values in returns
data_rolling.dropna(subset=["returns"], inplace=True)
# Out:
# /tmp/ipykernel_9684/1941895808.py:19: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.1' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#
# /tmp/ipykernel_9684/1941895808.py:43: FutureWarning:
#
# The 'method' keyword in Series.replace is deprecated and will be removed in a future version.

# %%
data_rolling["cum_returns"] = (1 + data_rolling["returns"]).cumprod()
data_rolling["all_in_return"] = (1 + data_rolling["Adj Close"].pct_change()).cumprod()

display(data_rolling.head(50))
# Out:
#          Date  Adj Close       Close        High         Low        Open  \
# 1  2018-01-31  95.394501  115.669998  116.660004  115.160004  115.650002
# 44 2018-04-04  91.534843  110.989998  111.209999  107.019997  107.099998
# 45 2018-04-05  92.736740  111.879997  112.830002  111.389999  111.629997
# 46 2018-04-06  90.424095  109.089996  111.550003  107.820000  110.550003
# 47 2018-04-09  91.509987  110.400002  112.980003  109.889999  110.010002
# 48 2018-04-10  93.258942  112.510002  112.870003  111.419998  112.129997
# 49 2018-04-11  91.692345  110.620003  111.809998  110.519997  111.660004
# 50 2018-04-12  93.971786  113.370003  114.389999  111.500000  111.559998
#
#       Volume       mean       std    zscore  signal  buy_signal  sell_signal  \
# 1   13141400  92.818508  2.414233  1.067003       0         NaN          NaN
# 2   13800600  93.204885  2.329993  1.364497       0         NaN          NaN
# 3   16477300  93.420961  2.207121  0.374787       0         NaN          NaN
# 4   30097600  93.439930  2.171632 -1.708952       0         NaN          NaN
# 5   33114800  93.588790  1.979540 -0.570980       0         NaN          NaN
# 6   21878300  93.746312  1.789726 -0.369326       0         NaN          NaN
# 7   27425800  93.648583  1.993664 -2.346729       1   88.969994          NaN
# 8   28188000  93.615594  2.037609 -1.405677       0         NaN          NaN
# 9   18043300  93.577245  2.058493 -0.691706       0         NaN          NaN
# 10  16358200  93.583842  2.055373 -0.419111       0         NaN          NaN
# 11  15186900  93.667963  2.072515  0.578386       0         NaN          NaN
# 12  12130200  93.760743  2.101547  0.714620       0         NaN          NaN
# 13  13214300  93.829607  2.104794  0.355582       0         NaN          NaN
# 14  13461500  93.845276  2.109559  0.359080       0         NaN          NaN
# 15  14212500  93.885687  2.124209  0.523942       0         NaN          NaN
# 16  17070400  93.857235  2.106674  0.459597       0         NaN          NaN
# 17  12162500  93.923623  2.178196  1.296204       0         NaN          NaN
# 18  16511200  94.024651  2.318518  1.693521       0         NaN          NaN
# 19  17563300  94.072485  2.367119  1.147295       0         NaN          NaN
# 20  17735600  94.088566  2.374351  0.490961       0         NaN          NaN
# 21  18690000  93.996199  2.356741 -0.190538       0         NaN          NaN
# 22  18353700  93.849812  2.290608 -0.171744       0         NaN          NaN
# 23  13933000  93.881974  2.300988  0.438700       0         NaN          NaN
# 24  10674400  94.144234  2.092135  0.396564       0         NaN          NaN
# 25  13006500  94.252272  2.055981  0.178503       0         NaN          NaN
# 26  11173700  94.329381  2.038759  0.146231       0         NaN          NaN
# 27  15366600  94.748335  1.714631  1.516792       0         NaN          NaN
# 28  12339300  95.062551  1.506842  1.309448       0         NaN          NaN
# 29  13312300  95.248524  1.350291  0.462357       0         NaN          NaN
# 30  12905100  95.352438  1.219270 -0.452523       0         NaN          NaN
# 31   8748000  95.361098  1.216250 -0.264106       0         NaN          NaN
# 32  19888900  95.358211  1.216564 -0.126099       0         NaN          NaN
# 33  13214900  95.352026  1.221046 -0.735185       0         NaN          NaN
# 34   9921200  95.349139  1.222977 -0.657484       0         NaN          NaN
# 35  13633000  95.330582  1.231362 -0.570971       0         NaN          NaN
# 36  22550400  95.123167  1.611597 -2.758766       1   90.677147          NaN
# 37  23081500  94.698441  2.180163 -2.956635       1   88.252495          NaN
# 38  20217500  94.349588  2.190486 -1.540999       0         NaN          NaN
# 39  18039900  93.970633  2.392654 -1.990038       0         NaN          NaN
# 40  19189300  93.661366  2.608054 -1.760863       0         NaN          NaN
# 41  13274600  93.518691  2.691352 -1.049671       0         NaN          NaN
# 42  18822500  93.293133  2.879319 -1.510041       0         NaN          NaN
# 43  14050700  93.056853  2.934622 -0.985147       0         NaN          NaN
# 44  15302600  92.884900  2.917084 -0.462810       0         NaN          NaN
# 45  16627000  92.790773  2.888406 -0.018707       0         NaN          NaN
# 46  18906000  92.580603  2.900627 -0.743463       0         NaN          NaN
# 47  15974300  92.288648  2.680949 -0.290442       0         NaN          NaN
# 48  13951400  92.099811  2.452240  0.472682       0         NaN          NaN
# 49  14503300  91.890786  2.286259 -0.086798       0         NaN          NaN
# 50  16435500  91.849341  2.237730  0.948481       0         NaN          NaN
#
#     dynamic_allocation  position   returns  cum_returns  all_in_return
# 1                  0.0       0.0  0.000000     1.000000            NaN
# 2                  0.0       0.0  0.000000     1.000000       1.010374
# 3                  0.0       0.0 -0.000000     1.000000       0.987983
# 4                  0.0       0.0 -0.000000     1.000000       0.940607
# 5                  0.0       0.0  0.000000     1.000000       0.969223
# 6                  0.0       0.0  0.000000     1.000000       0.975793
# 7                  0.1       0.1 -0.000000     1.000000       0.932653
# 8                  0.1       0.1  0.002002     1.002002       0.951327
# 9                  0.1       0.1  0.001545     1.003550       0.966024
# 10                 0.1       0.1  0.000617     1.004170       0.971989
# 11                 0.1       0.1  0.002313     1.006492       0.994467
# 12                 0.1       0.1  0.000417     1.006912       0.998617
# 13                 0.1       0.1 -0.000719     1.006189       0.991441
# 14                 0.1       0.1  0.000026     1.006215       0.991701
# 15                 0.1       0.1  0.000418     1.006636       0.995850
# 16                 0.1       0.1 -0.000182     1.006452       0.994035
# 17                 0.1       0.1  0.002026     1.008492       1.014178
# 18                 0.1       0.1  0.001245     1.009747       1.026800
# 19                 0.1       0.1 -0.001187     1.008548       1.014611
# 20                 0.1       0.1 -0.001585     1.006950       0.998530
# 21                 0.1       0.1 -0.001792     1.005145       0.980635
# 22                 0.1       0.1 -0.000097     1.005048       0.979683
# 23                 0.1       0.1  0.001535     1.006591       0.994726
# 24                 0.1       0.1  0.000087     1.006678       0.995591
# 25                 0.1       0.1 -0.000373     1.006303       0.991873
# 26                 0.1       0.1  0.000009     1.006311       0.991960
# 27                 0.1       0.1  0.002876     1.009206       1.020489
# 28                 0.1       0.1 -0.000322     1.008881       1.017204
# 29                 0.1       0.1 -0.001198     1.007672       1.005014
# 30                 0.1       0.1 -0.001118     1.006545       0.993775
# 31                 0.1       0.1  0.000252     1.006799       0.996283
# 32                 0.1       0.1  0.000174     1.006973       0.998011
# 33                 0.1       0.1 -0.000788     1.006180       0.990144
# 34                 0.1       0.1  0.000096     1.006276       0.991095
# 35                 0.1       0.1  0.000087     1.006364       0.991960
# 36                 0.2       0.2 -0.004175     1.002163       0.950549
# 37                 0.4       0.4 -0.005348     0.996803       0.925132
# 38                 0.4       0.4  0.012335     1.009099       0.953661
# 39                 0.4       0.4 -0.007760     1.001269       0.935160
# 40                 0.4       0.4 -0.000629     1.000639       0.933691
# 41                 0.4       0.4  0.007296     1.007940       0.950722
# 42                 0.4       0.4 -0.007711     1.000168       0.932394
# 43                 0.4       0.4  0.005489     1.005658       0.945189
# 44                 0.4       0.4  0.006073     1.011766       0.959540
# 45                 0.4       0.4  0.005252     1.017080       0.972139
# 46                 0.4       0.4 -0.009975     1.006934       0.947896
# 47                 0.4       0.4  0.004804     1.011771       0.959279
# 48                 0.4       0.4  0.007645     1.019506       0.977613
# 49                 0.4       0.4 -0.006719     1.012655       0.961191
# 50                 0.4       0.4  0.009944     1.022725       0.985086

# %%
fig = go.Figure()

# Add the cumulative returns line
fig.add_trace(go.Scatter(
    x=data_rolling["Date"],  # Assuming 'Date' is a column in the DataFrame
    y=data_rolling["cum_returns"],
    mode='lines',
    name='Cumulative Returns',
    line=dict(color='blue')  # Customize the color if needed
))

fig.add_trace(go.Scatter(
    x=data_rolling["Date"], 
    y=data_rolling["all_in_return"],
    mode='lines',
    name='All-In Return',
    line=dict(color='green')
))


fig.update_layout(
    title="Mean Reversion Strategy vs All-In Returns",
    xaxis_title="Date",
    yaxis_title="Cumulative Returns",
    legend=dict(orientation='h', yanchor='bottom', y=1.02, xanchor='right', x=1),
    template='plotly_white'
)

# Show the figure
fig.show()

# %%
data_rolling[
    (data_rolling["Date"] >= "2024-01-02") & (data_rolling["Date"] <= "2024-01-30")
]
# Out:
#            Date   Adj Close       Close        High         Low        Open  \
# 1490 2024-01-02  168.066666  172.080002  172.169998  168.910004  169.089996
# 1491 2024-01-03  167.334167  171.330002  172.039993  170.369995  171.860001
# 1492 2024-01-04  168.444626  171.410004  173.350006  170.539993  170.639999
# 1493 2024-01-05  169.289734  172.270004  173.380005  171.470001  171.470001
# 1494 2024-01-08  169.044083  172.020004  172.360001  169.490005  172.020004
# 1495 2024-01-09  167.707611  170.660004  171.789993  170.100006  171.619995
# 1496 2024-01-10  168.061386  171.020004  171.080002  168.949997  170.000000
# 1497 2024-01-11  167.353836  170.300003  170.360001  168.639999  170.330002
# 1498 2024-01-12  166.125443  169.050003  176.309998  168.899994  173.800003
# 1499 2024-01-16  165.083786  167.990005  168.089996  164.300003  164.869995
# 1500 2024-01-17  164.199356  167.089996  169.070007  166.490005  167.339996
# 1501 2024-01-18  164.523651  167.419998  167.529999  165.240005  167.119995
# 1502 2024-01-19  167.363647  170.309998  170.570007  167.080002  167.550003
# 1503 2024-01-22  167.167114  170.110001  171.979996  169.710007  170.460007
# 1504 2024-01-23  166.066498  168.990005  169.750000  168.440002  169.669998
# 1505 2024-01-24  167.550369  170.500000  171.009995  168.860001  169.360001
# 1506 2024-01-25  169.948151  172.940002  172.990005  170.910004  172.309998
# 1507 2024-01-26  169.299576  172.279999  173.059998  171.779999  172.610001
# 1508 2024-01-29  169.741791  172.729996  172.839996  171.300003  172.240005
# 1509 2024-01-30  173.220566  176.270004  176.759995  172.830002  172.830002
#
#         Volume        mean       std    zscore  signal  buy_signal  \
# 1490   9977400  160.364597  5.034553  1.529842       0         NaN
# 1491   9852300  161.016040  5.052149  1.250582       0         NaN
# 1492  11972500  161.723984  5.051437  1.330442       0         NaN
# 1493  10064200  162.555247  4.845884  1.389733       0         NaN
# 1494  11229900  163.350787  4.512223  1.261750       0         NaN
# 1495   9923600  163.995022  4.134575  0.897937       0         NaN
# 1496   9670200  164.628621  3.693873  0.929313       0         NaN
# 1497  11919500  165.157498  3.239743  0.677936       0         NaN
# 1498  19429200  165.598586  2.663457  0.197809       0         NaN
# 1499  17206400  165.844508  2.343205 -0.324650       0         NaN
# 1500  11107500  165.985654  2.135736 -0.836385       0         NaN
# 1501   9382300  166.094181  1.991726 -0.788527       0         NaN
# 1502  13114400  166.236297  1.974924  0.570832       0         NaN
# 1503  12837500  166.461370  1.794875  0.393200       0         NaN
# 1504   8360800  166.585020  1.667575 -0.310944       0         NaN
# 1505   9967100  166.787748  1.511397  0.504580       0         NaN
# 1506   8873500  167.062019  1.564072  1.845268       0         NaN
# 1507   7443000  167.254539  1.591824  1.284713       0         NaN
# 1508   6971200  167.425218  1.668436  1.388470       0         NaN
# 1509  10822100  167.779603  2.081169  2.614378      -1         NaN
#
#       sell_signal  dynamic_allocation  position   returns  cum_returns  \
# 1490          NaN                 0.0      -0.2 -0.002328     2.111211
# 1491          NaN                 0.0      -0.2  0.000872     2.113051
# 1492          NaN                 0.0      -0.2 -0.001327     2.110247
# 1493          NaN                 0.0      -0.2 -0.001003     2.108129
# 1494          NaN                 0.0      -0.2  0.000290     2.108741
# 1495          NaN                 0.0      -0.2  0.001581     2.112075
# 1496          NaN                 0.0      -0.2 -0.000422     2.111184
# 1497          NaN                 0.0      -0.2  0.000842     2.112962
# 1498          NaN                 0.0      -0.2  0.001468     2.116064
# 1499          NaN                 0.0      -0.2  0.001254     2.118717
# 1500          NaN                 0.0      -0.2  0.001071     2.120988
# 1501          NaN                 0.0      -0.2 -0.000395     2.120150
# 1502          NaN                 0.0      -0.2 -0.003452     2.112830
# 1503          NaN                 0.0      -0.2  0.000235     2.113326
# 1504          NaN                 0.0      -0.2  0.001317     2.116109
# 1505          NaN                 0.0      -0.2 -0.001787     2.112328
# 1506          NaN                 0.0      -0.2 -0.002862     2.106282
# 1507          NaN                 0.0      -0.2  0.000763     2.107889
# 1508          NaN                 0.0      -0.2 -0.000522     2.106788
# 1509   173.220566                 0.0      -0.2 -0.004099     2.098153
#
#       all_in_return
# 1490       1.761807
# 1491       1.754128
# 1492       1.765769
# 1493       1.774628
# 1494       1.772053
# 1495       1.758043
# 1496       1.761751
# 1497       1.754334
# 1498       1.741457
# 1499       1.730538
# 1500       1.721266
# 1501       1.724666
# 1502       1.754437
# 1503       1.752377
# 1504       1.740839
# 1505       1.756394
# 1506       1.781530
# 1507       1.774731
# 1508       1.779367
# 1509       1.815834
